# %% [markdown]
# ## 기초데이터과학 (01분반)
#
# ## Programming assignment 08

# %% [markdown]
# ### 1.Mauna Loa 관측소의 이산화탄소 농도 Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
url = "https://datahub.io/core/co2-ppm/r/co2-mm-mlo.csv"
data = pd.read_csv(url)

data.head()
# Out:
#               Date  Decimal Date  Average  Interpolated  Trend  Number of Days
# 1958-03  1958.2027        315.71   314.44            -1  -9.99           -0.99
# 1958-04  1958.2877        317.45   315.16            -1  -9.99           -0.99
# 1958-05  1958.3699        317.51   314.69            -1  -9.99           -0.99
# 1958-06  1958.4548        317.27   315.15            -1  -9.99           -0.99
# 1958-07  1958.5370        315.87   315.20            -1  -9.99           -0.99

# %% [markdown]
# #### 1-1. 2010-01부터 2023-12까지 데이터를 추출하고 'Average' 속성의 그래프를 출력하세요

# %%
# 2010년 1월 ~ 2023년 12월 데이터 추출


# 'Average' 속성 그래프 출력

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 1-2. 위에서 추출한 데이터에서 평균 이산화탄소 농도의 3개월, 6개월, 12개월 단순 이동 평균 데이터를 구하고 그래프로 출력하세요.

# %%
# 이동 평균 (Simple Moving Average)


# 결과 시각화 (SMA)

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 1-3. 3개월, 6개월, 12개월 지수 가중 이동 평균 데이터를 구하고 그래프로 출력하세요.

# %%
# 지수 가중 이동 평균 (Exponential Weighted Moving Average)


# 결과 시각화 (EWMA)

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ### 2. 태양 흑점 관측 기록 Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.seasonal import STL

# 데이터 로드 (Sunspot Numbers 데이터)
data = pd.read_csv('daily_sunspots_time_series_1850-01_2024-05.csv', parse_dates=["date"])

data.head()
# Out:
#         date  year  month  day  date_frac  counts   std  nobs indicator
# 0 1850-01-01  1850      1    1   1850.001     253  19.6     1       NaN
# 1 1850-01-02  1850      1    2   1850.004     162  15.5     1       NaN
# 2 1850-01-03  1850      1    3   1850.007     217  18.1     1       NaN
# 3 1850-01-04  1850      1    4   1850.010      99  12.0     1       NaN
# 4 1850-01-05  1850      1    5   1850.012     108  12.6     1       NaN

# %% [markdown]
# #### 2-1. 1900년 ~ 2024년 데이터 추출하고 그래프로 출력하세요.

# %%
# 'date' 속성을 인덱스로 설정


# 1900년 ~ 2024년 데이터 추출


# 'counts' 속성 그래프 출력

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 2-2. 1900년 ~ 2024년 흑점 폭발 횟수('counts') 데이터에 대해서 시계열 분해 결과 그래프를 출력하세요.

# %%
# 'Sunspot' 속성에 대해 seasonal_decompose로 시계열 분해 (Additive 모델)


# 결과 시각화

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 2-3. 1900년 ~ 2024년 흑점 폭발 횟수('counts') 데이터에 대해서 STL 방법으로 시계열 분해를 하고 그 결과 그래프를 출력하세요.

# %%
# STL 분해 적용


# 결과 시각화

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ### 3. 전 세계 주요 도시의 평균 기온 Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드 (Global Land Temperatures 데이터)
url = "https://raw.githubusercontent.com/datasets/global-temp/master/data/monthly.csv"
data = pd.read_csv(url)

data = data[data['Source'] == 'gcag']

data.tail()
# Out:
#      Source     Year    Mean
# 3818   gcag  2024-03  1.2515
# 3819   gcag  2024-04  1.2053
# 3820   gcag  2024-05  1.0745
# 3821   gcag  2024-06  1.1154
# 3822   gcag  2024-07  1.1398

# %% [markdown]
# #### 3-1. 2000년부터 2024년 데이터를 추출하고 온도 평균('Mean')데이터를 그래프로 출력하세요.

# %%
# 시간 인덱스를 'Year'로 설정


# 2000년 부터 2024년 데이터 추출


# 'Mean' 속성 그래프 출력

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 3-2. 추출된 온도 평균('Mean')데이터에 단순 이동 평균을 계산하고 출력하세요.

# %%
# 'Mean' 속성에 대해 12개월 단순 이동 평균 계산하고 'SMA_12' 속성에 저장


# 속성이 추가된 데이터 출력
# Out:
#         Source    Mean    SMA_12
# Year
# 2000-01   gcag  0.1813       NaN
# 2000-02   gcag  0.4992       NaN
# 2000-03   gcag  0.4450       NaN
# 2000-04   gcag  0.5384       NaN
# 2000-05   gcag  0.3058       NaN
# ...        ...     ...       ...
# 2023-08   gcag  1.1993  0.927883
# 2023-09   gcag  1.3522  0.974725
# 2023-10   gcag  1.2866  1.004533
# 2023-11   gcag  1.3338  1.059467
# 2023-12   gcag  1.2586  1.100317
#
# [288 rows x 3 columns]

# %%
# 이 셀을 실행하지 마시오.
# Out:
#         Source    Mean    SMA_12
# Year
# 2000-01   gcag  0.1813       NaN
# 2000-02   gcag  0.4992       NaN
# 2000-03   gcag  0.4450       NaN
# 2000-04   gcag  0.5384       NaN
# 2000-05   gcag  0.3058       NaN
# ...        ...     ...       ...
# 2023-08   gcag  1.1993  0.927883
# 2023-09   gcag  1.3522  0.974725
# 2023-10   gcag  1.2866  1.004533
# 2023-11   gcag  1.3338  1.059467
# 2023-12   gcag  1.2586  1.100317
#
# [288 rows x 3 columns]

# %% [markdown]
# #### 3-3. 추출된 온도 평균('Mean')데이터에 지수 가중 이동 평균을 계산하고 출력하세요.

# %%
# 'Mean' 속성에 대해 대해 EWMA 계산 (alpha=0.3)하고 'EWMA' 속성에 저장


# 속성이 추가된 데이터 출력
# Out:
#         Source    Mean    SMA_12      EWMA
# Year
# 2000-01   gcag  0.1813       NaN  0.181300
# 2000-02   gcag  0.4992       NaN  0.368300
# 2000-03   gcag  0.4450       NaN  0.403323
# 2000-04   gcag  0.5384       NaN  0.456650
# 2000-05   gcag  0.3058       NaN  0.402252
# ...        ...     ...       ...       ...
# 2023-08   gcag  1.1993  0.927883  1.064331
# 2023-09   gcag  1.3522  0.974725  1.150692
# 2023-10   gcag  1.2866  1.004533  1.191464
# 2023-11   gcag  1.3338  1.059467  1.234165
# 2023-12   gcag  1.2586  1.100317  1.241496
#
# [288 rows x 4 columns]

# %%
# 이 셀을 실행하지 마시오.
# Out:
#         Source    Mean    SMA_12      EWMA
# Year
# 2000-01   gcag  0.1813       NaN  0.181300
# 2000-02   gcag  0.4992       NaN  0.368300
# 2000-03   gcag  0.4450       NaN  0.403323
# 2000-04   gcag  0.5384       NaN  0.456650
# 2000-05   gcag  0.3058       NaN  0.402252
# ...        ...     ...       ...       ...
# 2023-08   gcag  1.1993  0.927883  1.064331
# 2023-09   gcag  1.3522  0.974725  1.150692
# 2023-10   gcag  1.2866  1.004533  1.191464
# 2023-11   gcag  1.3338  1.059467  1.234165
# 2023-12   gcag  1.2586  1.100317  1.241496
#
# [288 rows x 4 columns]

# %% [markdown]
# #### 3-4. 추출한 데이터를 그래프를 그려 비교하세요.

# %%
# 원 데이터, 이동 평균, EWMA 데이터 시각화

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ### 4. 가정의 전력 소비 Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드 (Electricity Consumption 데이터)
data = pd.read_csv('household_power_consumption.txt', sep=';', low_memory=False, na_values='?', parse_dates=["Date"], dayfirst=True)

data.tail()
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 2075254 2010-11-26  20:58:00                0.946                    0.0
# 2075255 2010-11-26  20:59:00                0.944                    0.0
# 2075256 2010-11-26  21:00:00                0.938                    0.0
# 2075257 2010-11-26  21:01:00                0.934                    0.0
# 2075258 2010-11-26  21:02:00                0.932                    0.0
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 2075254   240.43               4.0             0.0             0.0
# 2075255   240.00               4.0             0.0             0.0
# 2075256   239.82               3.8             0.0             0.0
# 2075257   239.70               3.8             0.0             0.0
# 2075258   239.55               3.8             0.0             0.0
#
#          Sub_metering_3
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# ...

# %% [markdown]
# #### 4-1. 2006년 11월 부터 2010년 11월까지 데이터를 추출하여 Global_active_power 수치를 그래프로 출력하세요.

# %%
# 시간 인덱스를 'Date'로 설정


# 2006년 11월 부터 2010년 11월 데이터 추출


# 'Global_active_power' 속성 그래프 출력

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 4-2. 'Global_active_power' 열을 일별 평균으로 리샘플링하고 결측값을 NA로 처리하세요.

# %%
# 'Global_active_power' 열을 일별('D') 평균으로 리샘플링


# 결측값 처리


# 데이터 출력
# Out:
# Date
# 2006-12-16    3.053475
# 2006-12-17    2.354486
# 2006-12-18    1.530435
# 2006-12-19    1.157079
# 2006-12-20    1.545658
#                 ...
# 2010-11-22    1.417733
# 2010-11-23    1.095511
# 2010-11-24    1.247394
# 2010-11-25    0.993864
# 2010-11-26    1.178230
# Freq: D, Name: Global_active_power, Length: 1442, dtype: float64

# %% [raw]
# Date
# 2006-12-16    3.053475
# 2006-12-17    2.354486
# 2006-12-18    1.530435
# 2006-12-19    1.157079
# 2006-12-20    1.545658
#                 ...
# 2010-11-22    1.417733
# 2010-11-23    1.095511
# 2010-11-24    1.247394
# 2010-11-25    0.993864
# 2010-11-26    1.178230
# Freq: D, Name: Global_active_power, Length: 1442, dtype: float64

# %% [markdown]
# #### 4-3. 4-2에서 처리된 일별 데이터에 대해 Seasonal Decompose, STL을 적용하고 두 결과를 출력해 비교해보세요.

# %%
# easonal Decompose 적용 (Additive 모델)


# STL (Seasonal and Trend decomposition using Loess) 적용


# 결과 비교 (plt의 subplot 사용)

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ####
