# %% [markdown]
# ## 기초데이터과학 (01분반)
#
# ## Programming assignment 06

# %% [markdown]
# ### 1. Wine quality Dataset로 각 문제에 맞게 코드를 작성하여 와인 품질과 알코올 함량 사아의 상관관계를 분석하세요.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터 불러오기
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(url, sep=';')

df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# #### 1-1. 데이터의 각 변수 간의 상관계수를 heatmap으로 출력하세요.

# %%
# heatmap 그래프 출력

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 1-2. 와인 품질(quality)과 알코올 함량(alcohol)의 요약 통계를 출력하세요.

# %%
# 'quality', 'alcohol' 속성 요약 통계 출력

# %%
# 이 셀을 실행하지 마시오.
# Out:
# Summary statistics for quality and alcohol:
#            quality      alcohol
# count  1599.000000  1599.000000
# mean      5.636023    10.422983
# std       0.807569     1.065668
# min       3.000000     8.400000
# 25%       5.000000     9.500000
# 50%       6.000000    10.200000
# 75%       6.000000    11.100000
# max       8.000000    14.900000

# %% [markdown]
# #### 1-3. 와인 품질과 알코올 함량의 관계 그래프를 출력하세요.

# %%
# 'quality', 'alcohol'의 pairplot 출력

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 1-4. 와인 품질과 알코올 함량의 상관계수를 출력하세요.

# %%
# 'quality', 'alcohol' 속성의 상관계수 출력

# %%
# 이 셀을 실행하지 마시오.
# Out:
# Correlation coefficient between quality and alcohol:
#           quality   alcohol
# quality  1.000000  0.476166
# alcohol  0.476166  1.000000

# %% [markdown]
# ### 2. Chipotle Dataset로 각 문제에 맞게 코드를 작성하여 가설검정을 수행하세요.
# #### 귀무가설 : item_price가 10 이상인 item 그룹과 10 미만인 item 그룹의 평균 주문 수량은 차이가 없다.
# #### 대립가설 : item_price가 10 이상인 item 그룹과 10 미만인 item 그룹의 평균 주문 수량은 차이가 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# Chipotle 데이터셋 불러오기
chipotle_url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipotle_df = pd.read_csv(chipotle_url, sep='\t')

chipotle_df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# #### 2-1. 가설 검정을 통해 비교할 두 데이터 집단을 추출하고 첫 5개 행을 출력하세요.

# %%
# 데이터 전처리 ('item_price'에 포함되어 있는 '$' 제거)


# 'item_price'가 10 미만인 item의 주문 수량과 10 초과인 item의 주문 수량을 각각 추출


# 추출한 데이터 출력

# %%
# 이 셀을 실행하지 마시오.
# Out:
# below $10
# 0    1
# 1    1
# 2    1
# 3    1
# 6    1
# Name: quantity, dtype: int64
#
# above $10
# 4     2
# 5     1
# 7     1
# 13    1
# 23    1
# Name: quantity, dtype: int64

# %% [markdown]
# #### 2-2. 두 데이터 집단의 평균을 구하여 출력하고 두 데이터 집단의 Boxplot 그래프를 그려 시각화하세요.

# %%
# 두 집단의 주문 수량 평균을 출력


# 두 집단 박스플롯 시각화

# %%
# 이 셀을 실행하지 마시오.
# Out:
# Below 10 group:  1.0475372279495991
# Above 10 group:  1.1628318584070796

# %% [markdown]
# #### 2-3. 두 데이터 집단에 대해 t-검정을 수행하세요.

# %%
# t-검정 수행 (정규분포를 따른다고 가정. 분산은 다르다고 가정.)


# 결과 출력

# %% [raw]
# T-statistic: -5.546943337486742, P-value: 3.551051684082279e-08

# %% [markdown]
# #### 2-4. 가설검정의 결론을 작성하세요.

# %% [markdown]
# ### 3. Titanic Dataset로 각 문제에 맞게 코드를 작성하여 가설검정을 수행하세요.
# #### 귀무가설 : 생존자와 비생존자의 평균 나이는 차이가 없다.
# #### 대립가설 : 생존자와 비생존자의 평균 나이는 차이가 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# 데이터 불러오기
titanic_url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
titanic_df = pd.read_csv(titanic_url)

titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### 3-1. 가설 검정을 통해 비교할 두 데이터 집단을 추출하고 첫 5개 행을 출력하세요.

# %%
# 'Survived'가 1인 집단과 0인 집단의 'Age' 변수값을 각각 추출
# 'Age' 변수값 중 결측값은 제거 (dropna)


# 출력

# %%
# 이 셀을 실행하지 마시오.
# Out:
# Ages of Survived Passengers
# 1    38.0
# 2    26.0
# 3    35.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64
#
# Ages of Not Survived Passengers
# 0     22.0
# 4     35.0
# 6     54.0
# 7      2.0
# 12    20.0
# Name: Age, dtype: float64

# %% [markdown]
# #### 3-2. 두 데이터 집단의 나이 평균을 구하여 출력하고 두 데이터 집단에 대한 Boxplot 그래프를 그려 시각화하세요.

# %%
# 두 집단의 나이 평균을 출력


# 두 데이터 집단 박스플롯 시각화

# %%
# 이 셀을 실행하지 마시오.
# Out:
# Survived:  28.343689655172415
# Not survived:  30.62617924528302

# %% [markdown]
# #### 3-3. 두 데이터 집단에 대해 t-검정을 수행하세요.

# %%
# t-검정 수행 (정규분포를 따른다고 가정. 분산은 다르다고 가정.)


# 결과 출력
# Out:
# T-statistic: -2.0460301043939704, P-value: 0.04118965162586639

# %% [raw]
# T-statistic: -2.0460301043939704, P-value: 0.04118965162586639

# %% [markdown]
# #### 3-4. 가설검정의 결론을 작성하세요.

# %% [markdown]
# ### 4. Wine quality Dataset로 각 문제에 맞게 코드를 작성하여 가설검정을 수행하세요.
# #### 귀무가설 : 고품질 와인(등급 ≥ 7)과 저품질 와인(등급 ≤ 5)의 pH 평균은 차이가 없다.
# #### 대립가설 : 고품질 와인(등급 ≥ 7)과 저품질 와인(등급 ≤ 5)의 pH 평균은 차이가 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# 데이터 불러오기
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(url, sep=';')

df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# #### 4-1. 가설 검정을 통해 비교할 두 데이터 집단을 추출하고 첫 5개 행을 출력하세요.

# %%
# 'quality' 속성이 7이상인 와인의 pH 데이터와 5 이하인 와인의 pH 데이터를 각각 추출


# 추출한 데이터 출력

# %%
# 이 셀을 실행하지 마시오.
# Out:
# pH of wine quality >= 7
# 7     3.39
# 8     3.36
# 16    3.30
# 37    3.23
# 62    3.38
# Name: pH, dtype: float64
#
# pH of wine quality <= 5
# 0    3.51
# 1    3.20
# 2    3.26
# 4    3.51
# 5    3.51
# Name: pH, dtype: float64

# %% [markdown]
# #### 4-2. 두 데이터 집단의 평균을 구하여 출력하고 두 데이터 집단에 대한 Boxplot 그래프를 그려 시각화하세요.

# %%
# 두 집단의 pH 평균을 출력


# 박스플롯 시각화

# %%
# 이 셀을 실행하지 마시오.
# Out:
# Quality <= 5:  3.3116532258064515
# Quality >= 7:  3.2888018433179727

# %% [markdown]
# #### 4-3. 두 데이터 집단에 대해 t-검정을 수행하세요.

# %%
# t-검정 수행 (정규분포를 따른다고 가정. 분산은 다르다고 가정.)


# 결과 출력
# Out:
# T-statistic: 1.9178575085294045, P-value: 0.055939471631093876

# %% [raw]
# T-statistic: 1.9178575085294045, P-value: 0.055939471631093876

# %% [markdown]
# #### 4-4. 가설검정의 결론을 작성하세요.

# %% [markdown]
# ####
